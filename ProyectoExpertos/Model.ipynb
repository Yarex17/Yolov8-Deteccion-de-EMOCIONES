# %%
from ultralytics import YOLO
import os

# %%
# Cargar el modelo
model = YOLO('yolov8n.pt')

# Ruta al archivo YAML con la configuración del conjunto de datos
dataset_yaml = r'C:\Users\yarex\Desktop\ProyectoExpertos\DataSet\data.yaml'

# Cargar los datos de entrenamiento desde el archivo YAML
model.train(data=dataset_yaml, epochs=200, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.1.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.15 🚀 Python-3.11.6 torch-2.2.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# ...

# %%
from ultralytics import YOLO
import os


# Obtener la ruta absoluta
model_path = r'C:\Users\yarex\Desktop\ProyectoExpertos\Train\best200.pt'

# Cargar el modelo
model = YOLO(model_path)
# image_path = r'C:\Users\yarex\Downloads\Proyecto Expertos\DataSet\test\images\1666604461494_jpg.rf.90c10690cb907b33f9a4b925e6479f49.jpg' #surprised
image_path = r'C:\Users\yarex\Desktop\ProyectoExpertos\DataSet\test\images\image_happy_22_jpg.rf.b2ba22b1bcc3b27c725cb57018f5d0fe.jpg'
# image_path = r'C:\Users\yarex\Downloads\Proyecto Expertos\DataSet\test\images\image_sad_086_jpg.rf.c5e775ff0f096d646296f7957bbea358.jpg' #sad
results = model(image_path)  # predict on an image
print(results)


# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

print(metrics)
# Out:
# image 1/1 C:\Users\yarex\Desktop\ProyectoExpertos\DataSet\test\images\image_happy_22_jpg.rf.b2ba22b1bcc3b27c725cb57018f5d0fe.jpg: 640x640 1 disgust, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprised'}
# obb: None
# orig_img: array([[[181, 183, 184],
#         [176, 178, 179],
#         [173, 175, 176],
#         ...,
#         [229, 226, 228],
#         [229, 226, 228],
#         [229, 226, 228]],
#
#        [[181, 183, 184],
#         [176, 178, 179],
#         [173, 175, 176],
#         ...,
#         [229, 226, 228],
#         [229, 226, 228],
#         [229, 226, 228]],
#
#        [[181, 183, 184],
#         [176, 178, 179],
#         [173, 175, 176],
#         ...,
# ...

# %%
import cv2
from ultralytics import YOLO

# Diccionario para mapear los nombres de las clases en inglés a español
class_names_es = {
    'angry': 'enojado',
    'disgust': 'disgusto',
    'fear': 'miedo',
    'happy': 'feliz',
    'neutral': 'neutral',
    'sad': 'triste',
    'surprised': 'sorprendido'
}

# Cargar el modelo entrenado
model = YOLO(model_path)

# Inicializar la cámara
cap = cv2.VideoCapture(0)  # 0 para la cámara predeterminada

while True:
    # Capturar una imagen de la cámara
    ret, frame = cap.read()

    # Realizar detección de emociones en la imagen
    results = model(frame)

    # Procesar los resultados
    for result in results:
        boxes = result.boxes
        for box in boxes:
            # Obtener la clase (emoción) y la probabilidad
            class_id = int(box.cls)
            class_name_en = model.names[class_id]
            class_name_es = class_names_es[class_name_en]  # Traducir el nombre de la clase a español
            probability = float(box.conf)

            # Dibujar el rectángulo delimitador y el nombre de la clase en la imagen
            x1, y1, x2, y2 = box.xyxy.tolist()[0]
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            cv2.putText(frame, f"{class_name_es} ({probability:.2f})", (int(x1), int(y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (36, 255, 12), 2)

    # Mostrar la imagen con las detecciones
    cv2.imshow('Deteccion de Emociones', frame)

    # Salir del bucle si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar recursos
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 surprised, 75.6ms
# Speed: 2.3ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 68.5ms
# Speed: 3.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 70.2ms
# Speed: 1.1ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 70.4ms
# Speed: 1.0ms preprocess, 70.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 78.1ms
# Speed: 1.0ms preprocess, 78.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 66.7ms
# Speed: 4.1ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surprised, 60.3ms
# ...
